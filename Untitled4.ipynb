# %%
import tifffile as tf
import matplotlib.pyplot as plt
import numpy as np
import os

def visualize_single_tif(file_path):
    """
    Loads an image from a TIF file and displays it.

    This function is designed to handle multi-dimensional TIF files 
    (like time-series or Z-stacks) by displaying the first slice.
    """
    if not os.path.exists(file_path):
        print(f"Error: File not found at '{file_path}'.")
        print("Please update the 'TIF_FILE_PATH' variable to a valid file path.")
        return

    print(f"Loading image from: {file_path}")
    
    try:
        # Load the TIF file into a NumPy array. This handles complex TIF formats.
        image_data = tf.imread(file_path)

        # Print basic information about the loaded data
        print(f"Data Shape: {image_data.shape}")
        print(f"Data Type (dtype): {image_data.dtype}")
        
        # Check if the data is multi-dimensional (e.g., [Time, Y, X] or [Z, Y, X])
        if image_data.ndim > 2:
            # Select the first plane (index 0) for visualization
            print("Detected multi-dimensional data. Visualizing the first slice.")
            image_slice = image_data[0, ...]
        else:
            # It's a standard 2D image [Y, X]
            image_slice = image_data

        # --- Visualization ---
        plt.figure(figsize=(8, 8))
        # Use the 'gray' colormap, common for scientific microscopy images
        plt.imshow(image_slice, cmap='gray') 
        plt.title(f"Visualizing TIF Image (Slice Shape: {image_slice.shape})")
        plt.colorbar(label='Pixel Intensity')
        plt.axis('off') # Hide axis labels
        plt.show()

    except Exception as e:
        print(f"An error occurred during TIF processing: {e}")
        print("Ensure your file is a valid TIFF format and the libraries are installed.")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import tifffile as tf
import os
from glob import glob
from tqdm import tqdm
# Import the external library for pre-trained segmentation models
import segmentation_models_pytorch as smp 

# --- 1. CONFIGURATION ---
# IMPORTANT: Replace this base path with the absolute path to your dataset root
BASE_PATH = "/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC"
# Indices 0 to 999 (1000 images)
TRAINING_INDICES = list(range(1000)) 
# Split for a small validation set
VAL_SPLIT = 100 

# Hyperparameters
NUM_EPOCHS = 30
BATCH_SIZE = 4
LEARNING_RATE = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

# --- 2. U-NET MODEL DEFINITION ---
# Replaced custom UNet with pre-trained UNet from segmentation_models_pytorch (smp)

# --- 3. DATASET CLASS ---

class CellSegmentationDataset(Dataset):
    """
    Custom Dataset for loading CTC-formatted TIF images and masks.
    Can combine several sequences like '01', '02', ...
    """
    def __init__(self, base_path, seq_ids=("01", "02"), indices=None):
        """
        Args:
            base_path (str): Root path to 'BF-C2DL-HSC'.
            seq_ids (iterable[str]): e.g. ("01", "02").
            indices (iterable[int] or None): frame indices (0..999). If None,
                                             try all 0..999.
        """
        self.image_paths = []
        self.mask_paths = []

        for seq in seq_ids:
            img_dir = os.path.join(base_path, seq)
            mask_dir = os.path.join(base_path, f"{seq}_ST", "SEG")
            indices = range(len(os.listdir(img_dir)))
            for idx in indices:
                idx_str = f"{idx:04d}"

                img_path = os.path.join(img_dir, f"t{idx_str}.tif")
                mask_path = os.path.join(mask_dir, f"man_seg{idx_str}.tif")

                if os.path.exists(img_path) and os.path.exists(mask_path):
                    self.image_paths.append(img_path)
                    self.mask_paths.append(mask_path)
                # else: silently skip missing pairs

        if len(self.image_paths) == 0:
            print("Warning: No valid dataset files found. Please check BASE_PATH.")
        else:
            print(f"Dataset initialized with {len(self.image_paths)} valid samples.")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = tf.imread(self.image_paths[idx]).astype(np.float32)
        mask = tf.imread(self.mask_paths[idx])

        # normalize image
        image = (image - np.mean(image)) / (np.std(image) + 1e-6)
        image = torch.from_numpy(image).unsqueeze(0)

        # binarize mask
        mask = mask.astype(np.int64)
        mask[mask > 0] = 1
        mask = torch.from_numpy(mask)

        return image, mask

# --- 4. METRICS & LOSS FUNCTION ---

def dice_coefficient(pred, target):
    """
    Computes the Sorensen-Dice Coefficient (DSC) for segmentation.
    
    Args:
        pred (torch.Tensor): Predicted mask (after argmax, should be 0 or 1).
        target (torch.Tensor): Ground truth mask (0 or 1).
    """
    smooth = 1e-6
    # Flatten the tensors for simple IoU calculation
    pred = pred.contiguous().view(-1)
    target = target.contiguous().view(-1)
    
    intersection = (pred * target).sum()
    
    # Dice = 2 * (Intersection) / (Sum of Areas)
    dice = (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)
    return dice

class DiceLoss(nn.Module):
    """
    Combination of Dice Loss and Cross Entropy Loss for stable training.
    """
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()
        self.cross_entropy = nn.CrossEntropyLoss()

    def forward(self, inputs, targets):
        # 1. Cross Entropy Loss (for primary gradient)
        # inputs is [B, C, H, W], targets is [B, H, W]
        ce_loss = self.cross_entropy(inputs, targets)

        # 2. Dice Loss (using the predicted probability of the positive class)
        
        # Softmax and get probability of the positive class (class 1: Cell)
        probs = torch.softmax(inputs, dim=1)[:, 1, :, :].float()
        targets_f = targets.float()
        
        # Flatten the tensors
        probs_f = probs.contiguous().view(-1)
        targets_f = targets_f.contiguous().view(-1)
        
        intersection = (probs_f * targets_f).sum()
        
        # Dice = 2 * Intersection / (Sum of Areas)
        dice_score = (2. * intersection) / (probs_f.sum() + targets_f.sum() + 1e-6)
        dice_loss = 1 - dice_score
        
        # Combine losses (e.g., 50/50 mix)
        total_loss = ce_loss + dice_loss * 0.5 
        
        return total_loss

# --- 5. TRAINING AND EVALUATION FUNCTIONS ---

def train_model(model, dataloader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    for inputs, masks in tqdm(dataloader,desc="Training epoch"):
        inputs = inputs.to(DEVICE)
        masks = masks.to(DEVICE)
        # if len(np.unique(masks.cpu()) != 2:
        #     print(f"Non-binary-mask")
        #print(f"[TRAIN-DEBUG]: mask unique {np.unique(mask)}")
        optimizer.zero_grad()
        
        outputs = model(inputs)
        
        preds = torch.softmax(outputs,dim = 1).cpu().detach().numpy()
        # if len(np.unique(preds)) != 2:
        #     print(f"Non-binary-prediction")
        #print(f"[TRAIN_DEBUG]: outputs unique {np.unique(preds)}")
        loss = criterion(outputs, masks)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
    
    # Check if dataloader.dataset is empty before dividing
    if len(dataloader.dataset) > 0:
        epoch_loss = running_loss / len(dataloader.dataset)
    else:
        epoch_loss = 0.0
    return epoch_loss

def evaluate_model(model, dataloader):
    model.eval()
    total_dice = 0.0
    total_samples = 0

    with torch.no_grad():
        for inputs, masks in tqdm(dataloader, desc="Validation epoch"):
            inputs = inputs.to(DEVICE)
            masks = masks.to(DEVICE)

            outputs = model(inputs)  # [B, 4, H, W] for 4-class model
            preds = torch.argmax(outputs, dim=1)  # [B, H, W]

            # === NEW: MAP 2,3 → 0 for both preds and masks ===
            preds_binary = preds.clone()
            masks_binary = masks.clone()

            preds_binary[preds_binary > 1] = 0
            masks_binary[masks_binary > 1] = 0

            # Calculate Dice
            batch_dice = 0.0
            B = inputs.size(0)
            for i in range(B):
                batch_dice += dice_coefficient(preds_binary[i], masks_binary[i])

            total_dice += batch_dice
            total_samples += B

    avg_dice = total_dice / total_samples if total_samples > 0 else 0.0
    return avg_dice

from scipy.ndimage import label  # at top of file
import numpy as np
from tqdm import tqdm

import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.ndimage import label  # or wherever your `label` is from

DEVICE = "cuda"  # or whatever you use


def evaluate_model_SEG(
    model,
    dataloader,
    seg_fail_threshold: float = 0.4,
    visualize_failures: bool = True,
):
    model.eval()
    total_seg = 0.0
    total_samples = 0

    failure_visualized = False  # make sure we only show ONE failure case

    with torch.no_grad():
        for inputs, gt_instance_masks in tqdm(dataloader, desc="Validation epoch"):
            inputs = inputs.to(DEVICE)

            # forward pass
            outputs = model(inputs)           # [B, 4, H, W]
            pred = torch.argmax(outputs, dim=1)  # [B, H, W], values 0..3

            fg = (pred == 1)  # bool mask for class 1
            fg_sep = fg

            fg_sep_np = fg_sep.cpu().numpy().astype(np.int32)
            pred_np_full = pred.cpu().numpy().astype(np.int32)  # full 0..3 labels

            B = inputs.size(0)
            for i in range(B):
                gt_instance_mask_np = gt_instance_masks[i].cpu().numpy().astype(np.int32)

                preds_binary_np = fg_sep_np[i]
                # if len(np.unique(gt_instance_mask_np)) != 2:
                #     print(f"Sample {i}: binary prediction not truly binary")
                    # print("Binary pixel counts:", np.unique(preds_binary_np, return_counts=True))

                # connected-component labeling -> predicted instances S
                preds_instance_np, _ = label(preds_binary_np, structure=None)

                # SEG score for this image
                current_seg_score = segmentation_accuracy_seg_measure(
                    preds_instance_np,
                    gt_instance_mask_np,
                )

                total_seg += current_seg_score
                total_samples += 1

                # ---- visualize failure case if below threshold and not yet plotted ----
                if (
                    visualize_failures
                    and not failure_visualized
                    and current_seg_score < seg_fail_threshold
                ):
                    failure_visualized = True
                    print(f"\n=== SEG failure case (SEG={current_seg_score:.4f}) ===")

                    # pixel counts per predicted *class* (0..3) for this image
                    pred_classes_img = pred_np_full[i]  # shape [H, W], values 0..3
                    classes, counts = np.unique(pred_classes_img, return_counts=True)
                    print("Predicted class pixel counts (class -> count):")
                    print({int(c): int(k) for c, k in zip(classes, counts)})

                    # if you also want GT instance-id distribution:
                    gt_ids, gt_counts = np.unique(gt_instance_mask_np, return_counts=True)
                    print("GT instance-id pixel counts (id -> count):")
                    print({int(c): int(k) for c, k in zip(gt_ids, gt_counts)})

                    # ---- basic visualization ----
                    # assume inputs: [B, C, H, W]; we visualize the first 3 channels if possible
                    inp_img = inputs[i].detach().cpu()
                    if inp_img.dim() == 3:
                        # [C, H, W] -> [H, W, C]
                        inp_img_vis = inp_img.permute(1, 2, 0).numpy()
                        # if single-channel, squeeze
                        if inp_img_vis.shape[2] == 1:
                            inp_img_vis = inp_img_vis[:, :, 0]
                    else:
                        # degenerate case: already [H, W]
                        inp_img_vis = inp_img.numpy()

                    fig, axs = plt.subplots(1, 3, figsize=(12, 4))

                    axs[0].set_title("Input image")
                    axs[0].imshow(inp_img_vis, cmap="gray")
                    axs[0].axis("off")

                    axs[1].set_title("GT instance mask")
                    im1 = axs[1].imshow(gt_instance_mask_np, cmap="tab20")
                    axs[1].axis("off")
                    fig.colorbar(im1, ax=axs[1], fraction=0.046, pad=0.04)

                    axs[2].set_title("Predicted instances (CCL on class 1)")
                    im2 = axs[2].imshow(preds_instance_np, cmap="tab20")
                    axs[2].axis("off")
                    fig.colorbar(im2, ax=axs[2], fraction=0.046, pad=0.04)

                    fig.suptitle(f"SEG failure (SEG={current_seg_score:.4f})", fontsize=14)
                    plt.tight_layout()
                    plt.show()

    avg_seg = total_seg / total_samples if total_samples > 0 else 0.0
    return avg_seg

def evaluate_model_SEG_multiclass(
    model,
    dataloader,
    seg_fail_threshold: float = 0.4,
    visualize_failures: bool = True,
):
    model.eval()
    total_seg = 0.0
    total_samples = 0

    failure_visualized = False  # make sure we only show ONE failure case

    with torch.no_grad():
        for inputs, gt_instance_masks in tqdm(dataloader, desc="Validation epoch"):
            inputs = inputs.to(DEVICE)
            if len(np.unique(gt_instance_masks) == 2) :
                continue
            print(f"Evaluating!")
            # forward pass
            outputs = model(inputs)           # [B, 4, H, W]
            pred = torch.argmax(outputs, dim=1)  # [B, H, W], values 0..3

            fg = (pred == 1)  # bool mask for class 1
            fg_sep = fg

            fg_sep_np = fg_sep.cpu().numpy().astype(np.int32)
            pred_np_full = pred.cpu().numpy().astype(np.int32)  # full 0..3 labels

            B = inputs.size(0)
            for i in range(B):
                gt_instance_mask_np = gt_instance_masks[i].cpu().numpy().astype(np.int32)

                preds_binary_np = fg_sep_np[i]
                if len(np.unique(preds_binary_np)) != 2:
                    print(f"Sample {i}: binary prediction not truly binary")
                    print("Binary pixel counts:", np.unique(preds_binary_np, return_counts=True))

                # connected-component labeling -> predicted instances S
                preds_instance_np, _ = label(preds_binary_np, structure=None)

                # SEG score for this image
                current_seg_score = segmentation_accuracy_seg_measure(
                    preds_instance_np,
                    gt_instance_mask_np,
                )

                total_seg += current_seg_score
                total_samples += 1

                # ---- visualize failure case if below threshold and not yet plotted ----
                if (
                    visualize_failures
                    and not failure_visualized
                    and current_seg_score < seg_fail_threshold
                ):
                    failure_visualized = True
                    print(f"\n=== SEG failure case (SEG={current_seg_score:.4f}) ===")

                    # pixel counts per predicted *class* (0..3) for this image
                    pred_classes_img = pred_np_full[i]  # shape [H, W], values 0..3
                    classes, counts = np.unique(pred_classes_img, return_counts=True)
                    print("Predicted class pixel counts (class -> count):")
                    print({int(c): int(k) for c, k in zip(classes, counts)})

                    # if you also want GT instance-id distribution:
                    gt_ids, gt_counts = np.unique(gt_instance_mask_np, return_counts=True)
                    print("GT instance-id pixel counts (id -> count):")
                    print({int(c): int(k) for c, k in zip(gt_ids, gt_counts)})

                    # ---- basic visualization ----
                    # assume inputs: [B, C, H, W]; we visualize the first 3 channels if possible
                    inp_img = inputs[i].detach().cpu()
                    if inp_img.dim() == 3:
                        # [C, H, W] -> [H, W, C]
                        inp_img_vis = inp_img.permute(1, 2, 0).numpy()
                        # if single-channel, squeeze
                        if inp_img_vis.shape[2] == 1:
                            inp_img_vis = inp_img_vis[:, :, 0]
                    else:
                        # degenerate case: already [H, W]
                        inp_img_vis = inp_img.numpy()

                    fig, axs = plt.subplots(1, 3, figsize=(12, 4))

                    axs[0].set_title("Input image")
                    axs[0].imshow(inp_img_vis, cmap="gray")
                    axs[0].axis("off")

                    axs[1].set_title("GT instance mask")
                    im1 = axs[1].imshow(gt_instance_mask_np, cmap="tab20")
                    axs[1].axis("off")
                    fig.colorbar(im1, ax=axs[1], fraction=0.046, pad=0.04)

                    axs[2].set_title("Predicted instances (CCL on class 1)")
                    im2 = axs[2].imshow(preds_instance_np, cmap="tab20")
                    axs[2].axis("off")
                    fig.colorbar(im2, ax=axs[2], fraction=0.046, pad=0.04)

                    fig.suptitle(f"SEG failure (SEG={current_seg_score:.4f})", fontsize=14)
                    plt.tight_layout()
                    plt.show()

    avg_seg = total_seg / total_samples if total_samples > 0 else 0.0
    return avg_seg
# Out:
# Using device: cuda

# %%
from torch.utils.data import random_split

# 1. Build full dataset from both 01 and 02
full_dataset = CellSegmentationDataset(
    BASE_PATH,
    seq_ids=("01", "02"),   # use both folders
    indices=None            # or range(1000)
)

if len(full_dataset) == 0:
    print("\nFATAL ERROR: No data found. Please check BASE_PATH.")
else:
    # 2. Randomly split: 90% train, 10% val
    num_total = len(full_dataset)
    num_val = max(1, int(0.1 * num_total))
    num_train = num_total - num_val

    train_dataset, val_dataset = random_split(
        full_dataset,
        lengths=[num_train, num_val],
        generator=torch.Generator().manual_seed(42)  # reproducible split
    )

    # 3. DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Dataset initialized with 3528 valid samples.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class JCrossEntropyLoss(nn.Module):
    def __init__(self, num_classes: int, lambda_val: float = 0.5,
                 reg_scale: float = 1.0, eps: float = 1e-6):
        """
        num_classes: C
        lambda_val:  λ_ik (here same for all i,k)
        reg_scale:   weight for the J-regularization term
        """
        super().__init__()
        self.C = num_classes
        self.lambda_val = lambda_val
        self.reg_scale = reg_scale
        self.eps = eps

    def forward(self, logits: torch.Tensor, target: torch.Tensor) -> torch.Tensor:
        """
        logits: [B, C, H, W]
        target: [B, H, W] with values in {0, ..., C-1}
        """
        B, C, H, W = logits.shape
        assert C == self.C

        # Softmax probabilities z(p)
        z = F.softmax(logits, dim=1)                  # [B, C, H, W]

        # Standard cross-entropy (first term), averaged over pixels
        ce = F.cross_entropy(logits, target, reduction='mean')

        # One-hot ground truth y_i(p)
        y = F.one_hot(target, num_classes=C)          # [B, H, W, C]
        y = y.permute(0, 3, 1, 2).float()             # [B, C, H, W]

        # Class pixel counts n_i over the whole batch
        n = y.sum(dim=(0, 2, 3)) + self.eps           # [C]
        # J-regularization term
        reg = logits.new_zeros(())                    # scalar

        # We sum over all pairs (i,k)
        for i in range(C):
            z_i = z[:, i, :, :]                       # [B, H, W]
            y_i = y[:, i, :, :]                       # [B, H, W]
            n_i = n[i]

            for k in range(C):
                y_k = y[:, k, :, :]                   # [B, H, W]
                n_k = n[k]

                # Δ_ik(p) = 0.5 * ( y_i/n_i - y_k/n_k )
                delta_ik = 0.5 * (y_i / n_i - y_k / n_k)    # [B, H, W]

                # S_ik = Σ_p z_i(p) * Δ_ik(p)
                S_ik = (z_i * delta_ik).sum()                # scalar

                val = 0.5 + S_ik
                # numerical safety: argument of log must be > 0
                val = torch.clamp(val, min=self.eps)

                reg = reg + self.lambda_val * torch.log(val)

        # Final loss: CE - sum λ log( ... )
        loss = ce - self.reg_scale * reg / (C * C)  # normalize by C^2 if you like
        return loss

# %%
# NUM_EPOCHS = 30
# model = smp.Unet(
#     encoder_name="resnet34",       # The backbone network (e.g., ResNet)
#     encoder_weights="imagenet",    # Use weights pre-trained on ImageNet
#     in_channels=1,                 # Input is 1-channel grayscale image
#     classes=2,                     # Output is 2 classes (Background and Cell)
# ).to(DEVICE)

# print(f"Initialized pre-trained UNet with ResNet34 encoder.")

# criterion = DiceLoss()
# optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# print(f"\n--- Starting Training on {len(train_dataset)} samples ---")

# # 3. Training Loop
# best_val_dice = 0.0

# for epoch in range(NUM_EPOCHS):
#     train_loss = train_model(model, train_loader, criterion, optimizer)
#     val_dice = evaluate_model(model, val_loader)

#     print(f"Epoch {epoch+1}/{NUM_EPOCHS}")
#     print(f"  Train Loss: {train_loss:.4f}")
#     print(f"  Validation Dice Coeff: {val_dice:.4f}")

#     # Simple saving of the best model based on validation Dice score
#     if val_dice > best_val_dice:
#         best_val_dice = val_dice
#         torch.save(model.state_dict(), "best_unet_model_pretrained.pth")
#         print("  -> Saved new best model!")
        
# print("\n--- Training Complete ---")
# print(f"Best Validation Dice Coefficient: {best_val_dice:.4f}")

# # 4. Final Evaluation (Optional, but good practice)
# # Reload the best model for final evaluation
# model.load_state_dict(torch.load("best_unet_model_pretrained.pth"))

# final_dice = evaluate_model(model, val_loader) 
# print(f"Final Test/Validation Dice Coefficient: {final_dice:.4f}")

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import tifffile as tf
import os
import matplotlib.pyplot as plt
import segmentation_models_pytorch as smp 
# Import for Connected Components Analysis (CCA) needed for instance segmentation metrics
from scipy.ndimage import label 

# --- 1. CONFIGURATION ---
# IMPORTANT: Update this BASE_PATH to the test data location
BASE_PATH = "/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC"
MODEL_PATH = "best_unet_model_pretrained.pth"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
N_SAMPLES_TO_VISUALIZE = 4 # How many test images to display
TRAINING_INDICES = list(range(1000)) # Assuming test data indices 0-99
VAL_SPLIT = 100
train_indices = TRAINING_INDICES[:-VAL_SPLIT]
val_indices = TRAINING_INDICES[-VAL_SPLIT:]
# --- 2. DATASET CLASS (Modified to return Instance IDs) ---


# --- 3. METRICS ---

def dice_coefficient(pred, target):
    """Computes the Sorensen-Dice Coefficient (DSC) for semantic segmentation (binary)."""
    smooth = 1e-6
    pred = pred.contiguous().view(-1)
    target = target.contiguous().view(-1)
    intersection = (pred * target).sum()
    # Dice = 2 * (Intersection) / (Sum of Areas)
    dice = (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)
    return dice.item()

def segmentation_accuracy_seg_measure(predicted_instance_mask, gt_instance_mask):
    """
    Computes the SEG measure (Segmentation Accuracy) based on Jaccard Index 
    and the detection matching criteria defined by the Cell Tracking Challenge.
    
    Args:
        predicted_instance_mask (np.ndarray): Predicted mask with instance IDs (S).
        gt_instance_mask (np.ndarray): Ground truth mask with instance IDs (R).
        
    Returns:
        float: The mean Jaccard Index (SEG Score) for all reference objects.
    """
    # Get all unique reference object IDs (R) excluding background (0)
    ref_ids = np.unique(gt_instance_mask)
    ref_ids = ref_ids[ref_ids != 0]
    #print(len(ref_ids))
    if len(ref_ids) == 0:
        return 1.0 # Perfect score if there are no objects to segment

    jaccard_scores = []

    # Iterate through each reference object R
    for ref_id in ref_ids:
        # Define R (Reference object mask)
        R_mask = (gt_instance_mask == ref_id)
        R_area = R_mask.sum()
        
        if R_area == 0: continue
            
        # Get unique predicted object IDs (S) that overlap with R
        S_overlap_ids = np.unique(predicted_instance_mask[R_mask])
        S_overlap_ids = S_overlap_ids[S_overlap_ids != 0] # Exclude background
        #print(len(S_overlap_ids))
        best_match_j = 0.0

        # Check for the matching segmented object S
        for pred_id in S_overlap_ids:
            # Define S (Segmented object mask)
            S_mask = (predicted_instance_mask == pred_id)
            
            # Intersection (I)
            intersection_mask = R_mask & S_mask
            intersection_area = intersection_mask.sum() # |R intersection S|
            
            # 1. Matching condition: |R intersection S| / |R| > 0.5
            if intersection_area / R_area > 0.5:
                # Match condition met. Calculate Jaccard Index J(S, R).
                S_area = S_mask.sum()
                union_area = R_area + S_area - intersection_area # |R union S|
                
                # Jaccard Index: J(S, R) = |R intersection S| / |R union S|
                jaccard_index = intersection_area / union_area if union_area > 0 else 0.0
                
                # Per the rules, at most one segmented object satisfies the detection test.
                # We take the best match found, although typically the first match is used.
                if jaccard_index > best_match_j:
                    best_match_j = jaccard_index
        
        # Record the best Jaccard score (0.0 if no match found)
        jaccard_scores.append(best_match_j)

    # The SEG measure is the mean Jaccard index
    return np.mean(jaccard_scores)


model = smp.Unet(
    encoder_name="resnet34",       
    encoder_weights=None,          
    in_channels=1,                 
    classes=2,                    
).to(DEVICE)

if not os.path.exists(MODEL_PATH):
    print(f"\nFATAL ERROR: Model weights not found at '{MODEL_PATH}'.")
    print("Please train the model first and ensure 'best_unet_model_pretrained.pth' is in the same directory.")
else:
    print(f"\nLoading weights from: {MODEL_PATH}")
    model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
    model.eval() # Set model to evaluation mode

    # --- 5. DATA LOADING AND INFERENCE ---
    # test_dataset = CellSegmentationDataset(BASE_PATH, val_indices)
    # test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    # print("\nStarting inference on test samples...")
    all_dice_scores = []
    all_seg_scores = [] # New list for SEG scores
    
    # test_iterator = iter(test_loader)
    
    # # --- 6. VISUALIZATION LOOP ---
    # fig, axes = plt.subplots(N_SAMPLES_TO_VISUALIZE, 3, figsize=(12, 4 * N_SAMPLES_TO_VISUALIZE))
    test_iterator = iter(val_loader)
    for i in range(len(val_loader)):
        
        try:
            # Get the next sample (masks is now GT Instance Mask)
            # gt_instance_mask_t is the R set (instance mask)
            inputs, gt_instance_mask_t = next(test_iterator)
        except StopIteration:
            print(f"Only processed {i} samples. End of dataset reached.")
            # Adjust figure size if less than N_SAMPLES_TO_VISUALIZE samples were processed
            if i > 0:
                fig.set_size_inches(12, 4 * i)
            break
        #print(np.unique(gt_instance_mask_t))
        inputs = inputs.to(DEVICE)
        gt_instance_mask_np = gt_instance_mask_t.squeeze(0).numpy() # R set (instance mask)
        
        # Derived Binary Mask for Dice
        gt_binary_mask_t = (gt_instance_mask_t > 0).float()
        
        with torch.no_grad():
            outputs = model(inputs)
        
        # Prediction: outputs is [1, 2, H, W]. argmax over channel dim (1)
        preds_binary_t = torch.argmax(outputs, dim=1) # Binary prediction tensor
        preds_binary_np = preds_binary_t.squeeze(0).cpu().numpy()
        
        # --- 7. METRIC CALCULATION ---
        #print(np.unique(preds_binary_np))
        # a) Dice Score (uses binary masks)
        current_dice = dice_coefficient(
            preds_binary_t.float(), 
            gt_binary_mask_t.to(DEVICE).float()
        )
        all_dice_scores.append(current_dice)
        
        # b) SEG Score (uses instance masks)
        # Generate Predicted Instances (S) from the U-Net's binary prediction using CCA
        preds_instance_np = preds_binary_np
        
        current_seg_score = segmentation_accuracy_seg_measure(preds_instance_np, gt_instance_mask_np)
        all_seg_scores.append(current_seg_score)
        
        # Original Image (Input)
        input_image_np = inputs.squeeze().cpu().numpy()
        
        # --- 8. PLOTTING ---
        
        # Col 1: Original Image
    #     ax1 = axes[i, 0] if N_SAMPLES_TO_VISUALIZE > 1 else axes[0]
    #     ax1.imshow(input_image_np, cmap='gray')
    #     ax1.set_title(f"Image (Index {i})")
    #     ax1.axis('off')
        
    #     # Col 2: Ground Truth Mask (Instance IDs)
    #     ax2 = axes[i, 1] if N_SAMPLES_TO_VISUALIZE > 1 else axes[1]
    #     # Use 'gist_ncar' colormap for instance visualization
    #     ax2.imshow(gt_instance_mask_np, cmap='gist_ncar') 
    #     ax2.set_title("Ground Truth Instances (R)")
    #     ax2.axis('off')

    #     # Col 3: Predicted Mask (SEG Score)
    #     ax3 = axes[i, 2] if N_SAMPLES_TO_VISUALIZE > 1 else axes[2]
    #     # Plot the predicted instances S
    #     ax3.imshow(preds_instance_np, cmap='gist_ncar') 
    #     ax3.set_title(f"Predicted Instances (S)\nDice: {current_dice:.4f} | SEG: {current_seg_score:.4f}")
    #     ax3.axis('off')
    
    # # Adjust layout and show plot
    # plt.tight_layout()
    # plt.suptitle(f"U-Net Segmentation Results on Test Data (N={len(all_dice_scores)})", y=1.02, fontsize=16)
    # plt.show()

    # Print overall average scores for the visualized batch
    if all_dice_scores:
        avg_dice = np.mean(all_dice_scores)
        avg_seg = np.mean(all_seg_scores)
        print(f"\n--- Evaluation Summary for Visualized Samples ---")
        print(f"Average Dice Score: {avg_dice:.4f}")
        print(f"Average SEG Score (Instance Accuracy): {avg_seg:.4f}")
# Out:
# Loading weights from: best_unet_model_pretrained.pth
#
# --- Evaluation Summary for Visualized Samples ---
# Average Dice Score: 0.9821
# Average SEG Score (Instance Accuracy): 0.9649

# %%
class CellSegmentationDatasetGT(Dataset):
    """
    Custom Dataset for loading CTC-formatted TIF images and masks.
    Can combine several sequences like '01', '02', ...
    """
    def __init__(self, base_path, seq_ids=("01", "02"), indices=None):
        """
        Args:
            base_path (str): Root path to 'BF-C2DL-HSC'.
            seq_ids (iterable[str]): e.g. ("01", "02").
            indices (iterable[int] or None): frame indices (0..999). If None,
                                             try all 0..999.
        """
        self.image_paths = []
        self.mask_paths = []

        for seq in seq_ids:
            img_dir = os.path.join(base_path, seq)
            mask_dir = os.path.join(base_path, f"{seq}_ST", "SEG")
            indices = range(len(os.listdir(img_dir)))
            for idx in indices:
                idx_str = f"{idx:04d}"

                img_path = os.path.join(img_dir, f"t{idx_str}.tif")
                mask_path = os.path.join(mask_dir, f"man_seg{idx_str}.tif")

                if os.path.exists(img_path) and os.path.exists(mask_path):
                    self.image_paths.append(img_path)
                    self.mask_paths.append(mask_path)
                # else: silently skip missing pairs

        if len(self.image_paths) == 0:
            print("Warning: No valid dataset files found. Please check BASE_PATH.")
        else:
            print(f"Dataset initialized with {len(self.image_paths)} valid samples.")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = tf.imread(self.image_paths[idx]).astype(np.float32)
        mask = tf.imread(self.mask_paths[idx])

        # normalize image
        image = (image - np.mean(image)) / (np.std(image) + 1e-6)
        image = torch.from_numpy(image).unsqueeze(0)

        # binarize mask
        mask = mask.astype(np.int64)
        mask = torch.from_numpy(mask)

        return image, mask

# %%
from torch.utils.data import random_split

# 1. Build full dataset from both 01 and 02
full_dataset_GT = CellSegmentationDatasetGT(
    BASE_PATH,
    seq_ids=("01", "02"),   # use both folders
    indices=None            # or range(1000)
)

if len(full_dataset) == 0:
    print("\nFATAL ERROR: No data found. Please check BASE_PATH.")
else:
    # 2. Randomly split: 90% train, 10% val
    num_total = len(full_dataset)
    num_val = max(1, int(0.1 * num_total))
    num_train = num_total - num_val

    train_dataset, val_dataset = random_split(
        full_dataset_GT,
        lengths=[num_train, num_val],
        generator=torch.Generator().manual_seed(42)  # reproducible split
    )

    # 3. DataLoaders
    train_loader_GT = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader_GT   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False)
    print(len(val_loader_GT))
# Out:
# Dataset initialized with 3528 valid samples.
# 88

# %%
# mask = tf.imread("/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC/01_GT/SEG/man_seg0058.tif")
# gt_instance_mask = mask.astype(np.int64)
# gt_instance_mask_t = torch.from_numpy(gt_instance_mask) # [H, W] instance mask
# print(np.unique(gt_instance_mask_t))

# %%
# visualize_single_tif("/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC/01_GT/SEG/man_seg0000.tif")

# %%
# val_GT = CellSegmentationDatasetGT(base_path = "/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC/01", GT_path = "/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC/01_GT/SEG")
# val_loader_GT = DataLoader(val_GT, batch_size = 1, shuffle = False)

# %%
# print(val_GT.image_paths)
# print(val_GT.mask_paths)

# %%
model = smp.Unet(
    encoder_name="resnet34",       
    encoder_weights=None,          
    in_channels=1,                 
    classes=2,                    
).to(DEVICE)
cnt = 0
if not os.path.exists(MODEL_PATH):
    print(f"\nFATAL ERROR: Model weights not found at '{MODEL_PATH}'.")
    print("Please train the model first and ensure 'best_unet_model_pretrained.pth' is in the same directory.")
else:
    print(f"\nLoading weights from: {MODEL_PATH}")
    model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
    model.eval() # Set model to evaluation mode

    # --- 5. DATA LOADING AND INFERENCE ---
    # test_dataset = CellSegmentationDataset(BASE_PATH, val_indices)
    # test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    # print("\nStarting inference on test samples...")
    all_dice_scores = []
    all_seg_scores = [] # New list for SEG scores
    
    # test_iterator = iter(test_loader)
    
    # # --- 6. VISUALIZATION LOOP ---
    fig, axes = plt.subplots(N_SAMPLES_TO_VISUALIZE, 3, figsize=(12, 4 * N_SAMPLES_TO_VISUALIZE))
    test_iterator = iter(val_loader_GT)
    for i in range(len(val_loader_GT)):
        
        try:
            # Get the next sample (masks is now GT Instance Mask)
            # gt_instance_mask_t is the R set (instance mask)
            inputs, gt_instance_mask_t = next(test_iterator)
        except StopIteration:
            print(f"Only processed {i} samples. End of dataset reached.")
            # Adjust figure size if less than N_SAMPLES_TO_VISUALIZE samples were processed
            if i > 0:
                fig.set_size_inches(12, 4 * i)
            break
        #print(np.unique(gt_instance_mask_t))
        inputs = inputs.to(DEVICE)
        gt_instance_mask_np = gt_instance_mask_t.squeeze(0).numpy() # R set (instance mask)
        
        # Derived Binary Mask for Dice
        gt_binary_mask_t = (gt_instance_mask_t > 0).float()
        
        with torch.no_grad():
            outputs = model(inputs)
        
        # Prediction: outputs is [1, 2, H, W]. argmax over channel dim (1)
        preds_binary_t = torch.argmax(outputs, dim=1) # Binary prediction tensor
        preds_binary_np = preds_binary_t.squeeze(0).cpu().numpy()
        
        # --- 7. METRIC CALCULATION ---
        #print(np.unique(preds_binary_np))
        # a) Dice Score (uses binary masks)
        current_dice = dice_coefficient(
            preds_binary_t.float(), 
            gt_binary_mask_t.to(DEVICE).float()
        )
        all_dice_scores.append(current_dice)
        
        # b) SEG Score (uses instance masks)
        # Generate Predicted Instances (S) from the U-Net's binary prediction using CCA
        preds_instance_np, _  = label(preds_binary_np, structure=None)
        print(len(np.unique(preds_instance_np)))
        print(len(np.unique(gt_binary_mask_t)))
        print("="*100)
        current_seg_score = segmentation_accuracy_seg_measure(preds_instance_np, gt_instance_mask_np)
        all_seg_scores.append(current_seg_score)
        #print(current_seg_score)
        # Original Image (Input)
        input_image_np = inputs.squeeze().cpu().numpy()
        # --- 8. PLOTTING ---
        # if current_seg_score < 0.25:
        #     print(np.unique(gt_instance_mask_np))
        #     # Col 1: Original Image
        #     ax1 = axes[cnt, 0] if N_SAMPLES_TO_VISUALIZE > 1 else axes[0]
        #     ax1.imshow(input_image_np, cmap='gray')
        #     ax1.set_title(f"Image (Index {i})")
        #     ax1.axis('off')
            
        #     # Col 2: Ground Truth Mask (Instance IDs)
        #     ax2 = axes[cnt, 1] if N_SAMPLES_TO_VISUALIZE > 1 else axes[1]
        #     # Use 'gist_ncar' colormap for instance visualization
        #     ax2.imshow(gt_instance_mask_np, cmap='gist_ncar') 
        #     ax2.set_title("Ground Truth Instances (R)")
        #     ax2.axis('off')
    
        #     # Col 3: Predicted Mask (SEG Score)
        #     ax3 = axes[cnt, 2] if N_SAMPLES_TO_VISUALIZE > 1 else axes[2]
        #     # Plot the predicted instances S
        #     ax3.imshow(preds_instance_np, cmap='gist_ncar') 
        #     ax3.set_title(f"Predicted Instances (S)\nDice: {current_dice:.4f} | SEG: {current_seg_score:.4f}")
        #     ax3.axis('off')

        #     cnt += 1
    
    # Adjust layout and show plot
    plt.tight_layout()
    plt.suptitle(f"U-Net Segmentation Results on Test Data (N={len(all_dice_scores)})", y=1.02, fontsize=16)
    plt.show()

    # Print overall average scores for the visualized batch
    if all_dice_scores:
        avg_dice = np.mean(all_dice_scores)
        avg_seg = np.mean(all_seg_scores)
        print(f"\n--- Evaluation Summary for Visualized Samples ---")
        print(f"Average Dice Score: {avg_dice:.4f}")
        print(f"Average SEG Score (Instance Accuracy): {avg_seg:.4f}")
# Out:
# Loading weights from: best_unet_model_pretrained.pth
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 27
#      23 # test_iterator = iter(test_loader)
#      24
#      25 # # --- 6. VISUALIZATION LOOP ---
#      26 fig, axes = plt.subplots(N_SAMPLES_TO_VISUALIZE, 3, figsize=(12, 4 * N_SAMPLES_TO_VISUALIZE))
# ---> 27 test_iterator = iter(val_loader_GT)
#      28 for i in range(len(val_loader_GT)):
#      30     try:
#      31         # Get the next sample (masks is now GT Instance Mask)
#      32         # gt_instance_mask_t is the R set (instance mask)
#
# NameError: name 'val_loader_GT' is not defined

# %%
import numpy as np
import scipy.ndimage as ndi

def make_4class_labels(mask: np.ndarray,
                       ring_width: int = 1) -> np.ndarray:
    """
    Convert an instance mask (0=background, >0=cell IDs)
    into a 4-class mask:
        0 = background
        1 = cell interior
        2 = near-cell outer ring (thin band outside cells)
        3 = between-cell interface (thin boundaries between different cells)
    """
    mask = mask.astype(np.int32)
    H, W = mask.shape

    # 0: start with all background
    labels = np.zeros_like(mask, dtype=np.int64)

    # Union of cells
    cell_union = mask > 0

    # ------------------------------------------
    # Class 3: between-cell interface
    # ------------------------------------------
    # Pixels where neighbors have different nonzero labels
    interface = np.zeros_like(cell_union, dtype=bool)
    for dy, dx in [(-1, 0), (1, 0), (0, -1), (0, 1)]:  # 4-neighbor
        shifted = np.roll(mask, shift=(dy, dx), axis=(0, 1))
        different_nonzero = (mask > 0) & (shifted > 0) & (mask != shifted)
        interface |= different_nonzero

    # optional: restrict interface to a thin band
    # (already essentially 1-pixel thick, but you could dilate if you want wider)
    labels[interface] = 3

    # ------------------------------------------
    # Class 2: near-cell ring outside cells
    # ------------------------------------------
    # Use binary dilation - the union of cells, then remove cells & interface
    struct = ndi.generate_binary_structure(2, 1)  # 4-connectivity
    dilated = ndi.binary_dilation(cell_union, structure=struct,
                                  iterations=ring_width)
    outer_ring = dilated & ~cell_union

    # Don’t overwrite interface if you later enlarge it
    labels[outer_ring & ~interface] = 2

    # ------------------------------------------
    # Class 1: cell interior (excluding interface)
    # ------------------------------------------
    cell_interior = cell_union & ~interface
    labels[cell_interior] = 1

    # Class 0 stays as labels==0 (background far from cells)
    return labels

import matplotlib.pyplot as plt

def visualize_samples(dataset, k):
    """
    Plot original image, original instance mask, and 4-class labels
    for the first n samples.
    """
    fig, axes = plt.subplots(1, 3, figsize=(10, 3 * 1))

    img = tf.imread(dataset.image_paths[k]).astype(np.float32)
    raw_mask = tf.imread(dataset.mask_paths[k]).astype(np.int64)

    # 4-class label
    label_4class = make_4class_labels(raw_mask, ring_width=1)
    print(np.unique(label_4class))
    ax_img, ax_raw, ax_lbl = axes

    ax_img.imshow(img, cmap="gray")
    ax_img.set_title("Raw image")
    ax_img.axis("off")

    ax_raw.imshow(raw_mask, cmap="tab20")
    ax_raw.set_title("Original instance mask")
    ax_raw.axis("off")

    im = ax_lbl.imshow(label_4class, cmap="tab10", vmin=0, vmax=3)
    ax_lbl.set_title("4-class label (0/1/2/3)")
    ax_lbl.axis("off")

    plt.tight_layout()
    plt.show()

# %%
class CellSegmentationDatasetExtraClass(Dataset):
    def __init__(self, base_path, seq_ids=("01", "02"), indices=None, ring_length=1):
        self.image_paths = []
        self.mask_paths = []
        self.ring_length = ring_length
        for seq in seq_ids:
            img_dir = os.path.join(base_path, seq)
            mask_dir = os.path.join(base_path, f"{seq}_ST", "SEG")
            indices = range(len(os.listdir(img_dir)))
            for idx in indices:
                idx_str = f"{idx:04d}"
                img_path = os.path.join(img_dir, f"t{idx_str}.tif")
                mask_path = os.path.join(mask_dir, f"man_seg{idx_str}.tif")

                if os.path.exists(img_path) and os.path.exists(mask_path):
                    self.image_paths.append(img_path)
                    self.mask_paths.append(mask_path)

        if len(self.image_paths) == 0:
            print("Warning: No valid dataset files found. Please check BASE_PATH.")
        else:
            print(f"Dataset initialized with {len(self.image_paths)} valid samples.")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = tf.imread(self.image_paths[idx]).astype(np.float32)
        mask = tf.imread(self.mask_paths[idx])

        # normalize image
        image = (image - np.mean(image)) / (np.std(image) + 1e-6)
        image = torch.from_numpy(image).unsqueeze(0)  # [1, H, W]

        # instance -> 4-class semantic mask
        mask_np = mask.astype(np.int64)
        label_4class = make_4class_labels(mask_np, ring_width=self.ring_length)

        label_4class = torch.from_numpy(label_4class.astype(np.int64))

        return image, label_4class

# %%
full_dataset_extra_class = CellSegmentationDatasetExtraClass(
    BASE_PATH,
    seq_ids=("01", "02"),
    indices=None,
    ring_length = 5
)


num_total = len(full_dataset_extra_class)
num_val = max(1, int(0.1 * num_total))
num_train = num_total - num_val

train_dataset_extra_class, val_dataset_extra_class = random_split(
    full_dataset_extra_class,
    lengths=[num_train, num_val],
    generator=torch.Generator().manual_seed(42)  # reproducible split
)

# 3. DataLoaders
train_loader_extra_class = DataLoader(train_dataset_extra_class, batch_size=BATCH_SIZE, shuffle=True)
val_loader_extra_class   = DataLoader(val_dataset_extra_class,   batch_size=BATCH_SIZE, shuffle=False)

print(len(train_loader_extra_class))
# Out:
# Dataset initialized with 3528 valid samples.
# 794

# %%
# # Load from warmup and prepare for 4 class training

# import torch
# import segmentation_models_pytorch as smp

# DEVICE = "cuda"  # or "cpu"
# two_class_ckpt = "./best_unet_model_pretrained.pth"
# # 1. Recreate the 2-class model and load its weights
# model_2c = smp.Unet(
#     encoder_name="resnet34",
#     encoder_weights="imagenet",
#     in_channels=1,
#     classes=2,
# ).to(DEVICE)
# model_2c.load_state_dict(torch.load(two_class_ckpt, map_location=DEVICE))

# # 2. Create a new 4-class model
# model_4c = smp.Unet(
#     encoder_name="resnet34",
#     encoder_weights=None,   # we'll initialize from model_2c instead
#     in_channels=1,
#     classes=4,              # <-- 4 classes now
# ).to(DEVICE)

# state_2c = model_2c.state_dict()
# state_4c = model_4c.state_dict()

# # Keep only keys that exist in new model AND have the same shape
# filtered_state = {
#     k: v for k, v in state_2c.items()
#     if k in state_4c and state_4c[k].shape == v.shape
# }

# # Update and load
# state_4c.update(filtered_state)
# model_4c.load_state_dict(state_4c)

# print("Loaded encoder+decoder weights from 2-class model into 4-class model.")

# %%
# Load trained 4c model

import torch
import segmentation_models_pytorch as smp

best_model_4c_path = "./best_unet_4c_model_pretrained.pth"
model_4c = smp.Unet(
    encoder_name="resnet34",
    encoder_weights=None,
    in_channels=1,
    classes=4,      
).to(DEVICE)
best_model_4c = torch.load(best_model_4c_path)
model_4c.load_state_dict(best_model_4c)
# Out:
# <All keys matched successfully>

# %%
# # Check mask size

# for image, mask in train_loader_extra_class:
#     if len(np.unique(mask)) != 2:
#         print("Non binary mask")

# %%
import numpy as np
import torch
from tqdm import tqdm

def evaluate_multiclass_metrics(model, dataloader, num_classes=4):
    model.eval()

    # Confusion counts per class
    correct_per_class = [0 for _ in range(num_classes)]
    total_per_class   = [0 for _ in range(num_classes)]

    # Dice statistics
    intersection = [0 for _ in range(num_classes)]
    union        = [0 for _ in range(num_classes)]
    pred_sum     = [0 for _ in range(num_classes)]
    gt_sum       = [0 for _ in range(num_classes)]

    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Eval per-class"):
            images = images.to(DEVICE)
            labels = labels.to(DEVICE)  # [B, H, W], values in {0,1,2,3}

            # model predictions
            logits = model(images)                # [B, 4, H, W]
            preds = torch.argmax(logits, dim=1)   # [B, H, W]

            for cls in range(num_classes):
                # masks
                gt_mask   = (labels == cls)
                pred_mask = (preds  == cls)

                correct_per_class[cls] += (pred_mask & gt_mask).sum().item()
                total_per_class[cls]   += gt_mask.sum().item()

                # Dice numerators
                intersection[cls] += (pred_mask & gt_mask).sum().item()
                pred_sum[cls]      += pred_mask.sum().item()
                gt_sum[cls]        += gt_mask.sum().item()

                # IoU union
                union[cls] += ((pred_mask | gt_mask).sum().item())

    # Build metric dictionary
    metrics = {}

    # Per-class accuracy
    for cls in range(num_classes):
        if total_per_class[cls] == 0:
            metrics[f"acc_class_{cls}"] = float('nan')
        else:
            metrics[f"acc_class_{cls}"] = correct_per_class[cls] / total_per_class[cls]

    # Per-class Dice
    for cls in range(num_classes):
        if pred_sum[cls] + gt_sum[cls] == 0:
            metrics[f"dice_class_{cls}"] = float('nan')
        else:
            metrics[f"dice_class_{cls}"] = (
                2 * intersection[cls] / (pred_sum[cls] + gt_sum[cls])
            )

    # Per-class IoU
    for cls in range(num_classes):
        if union[cls] == 0:
            metrics[f"iou_class_{cls}"] = float('nan')
        else:
            metrics[f"iou_class_{cls}"] = intersection[cls] / union[cls]

    return metrics

# %%
NUM_EPOCHS_4c = 30

#criterion = JCrossEntropyLoss(num_classes=4, lambda_val=0.5, reg_scale=1.0)
LEARNING_RATE = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_4c.parameters(), lr=LEARNING_RATE)

print(f"\n--- Starting 4 classTraining on {len(train_dataset)} samples ---")

# 3. Training Loop
best_val_dice = 0.0
val_dice = evaluate_model_SEG(model_4c, val_loader)
val_metrics = evaluate_multiclass_metrics(model_4c, val_loader_extra_class)
print(f"Val metrics {val_metrics}")
for epoch in range(NUM_EPOCHS):
    train_loss = train_model(model_4c, train_loader_extra_class, criterion, optimizer)
    val_dice = evaluate_model_SEG(model_4c, val_loader)
    val_metrics = evaluate_multiclass_metrics(model_4c, val_loader_extra_class)
    print(f"Epoch {epoch+1}/{NUM_EPOCHS}")
    print(f"  Train Loss: {train_loss:.4f}")
    print(f"  Validation SEG: {val_dice:.4f}")
    print(f"Val metrics {val_metrics}")
    # Simple saving of the best model based on validation Dice score
    if val_dice > best_val_dice:
        best_val_dice = val_dice
        torch.save(model_4c.state_dict(), "best_unet_4c_model_pretrained_copy.pth")
        print("  -> Saved new best model!")
        
print("\n--- Training Complete ---")
print(f"Best Validation SEG Coefficient: {best_val_dice:.4f}")

# 4. Final Evaluation (Optional, but good practice)
# Reload the best model for final evaluation
model_4c.load_state_dict(torch.load("best_unet_4c_model_pretrained_copy.pth"))

final_SEG = evaluate_model_SEG(model_4c, val_loader_extra_class) 
print(f"Final Test/Validation SEG: {final_SEG:.4f}")

final_dice = evaluate_model(model_4c, val_loader_extra_class) 
print(f"Final Test/Validation Dice Coefficient: {final_dice:.4f}")

# %%
cnt = 0
# val_GT = CellSegmentationDatasetGT(base_path = "/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC/01", GT_path = "/home/cpsc4710_yp338/BF-C2DL-HSC-train/BF-C2DL-HSC/01_GT/SEG")
# val_loader_GT = DataLoader(val_GT, batch_size = 1, shuffle = False)
model_4c.eval()
#val_metrics = evaluate_multiclass_metrics(model_4c, val_loader_extra_class)
# val_dice = evaluate_model_SEG(model_4c, val_loader_GT)
#val_dice_original = evaluate_model_SEG(model, val_loader)
#print(val_metrics)
val_dice_4c = evaluate_model_SEG(model_4c, val_loader_GT)
print(val_dice_4c)
val_dice = evaluate_model_SEG(model, val_loader_GT)
print(val_dice)
#print(val_dice_original)
# Out:
# Validation epoch: 100%|██████████| 88/88 [00:26<00:00,  3.27it/s]
# 0.90518513915355
# Validation epoch:   0%|          | 0/88 [00:00<?, ?it/s]
# === SEG failure case (SEG=0.0392) ===
# Predicted class pixel counts (class -> count):
# {0: 997345, 1: 22755}
# GT instance-id pixel counts (id -> count):
# {0: 997413, 85: 572, 110: 404, 113: 331, 119: 304, 123: 277, 125: 362, 126: 339, 128: 351, 129: 372, 130: 414, 132: 325, 133: 340, 135: 348, 137: 299, 139: 343, 142: 337, 145: 385, 147: 340, 148: 328, 150: 312, 153: 310, 155: 387, 157: 379, 159: 365, 160: 330, 164: 316, 166: 366, 176: 307, 177: 295, 179: 387, 180: 303, 181: 279, 183: 328, 184: 293, 186: 245, 196: 280, 197: 279, 198: 331, 200: 320, 203: 292, 205: 310, 206: 250, 208: 277, 220: 308, 221: 333, 223: 289, 224: 330, 228: 229, 230: 274, 231: 308, 232: 278, 234: 371, 235: 317, 238: 272, 239: 278, 241: 261, 242: 262, 244: 269, 245: 233, 247: 279, 248: 294, 250: 260, 251: 236, 253: 268, 254: 286, 255: 206, 257: 237, 259: 226, 260: 242, 262: 286, 263: 284, 625: 327, 626: 332}
# Validation epoch: 100%|██████████| 88/88 [00:26<00:00,  3.35it/s]
# 0.519375339612398

# %%
# Boundary-aware model evaluation

cnt = 0

model_4c.eval()

# --- 5. DATA LOADING AND INFERENCE ---
# test_dataset = CellSegmentationDataset(BASE_PATH, val_indices)
# test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
# print("\nStarting inference on test samples...")
all_dice_scores = []
all_seg_scores = [] # New list for SEG scores

# test_iterator = iter(test_loader)

# # --- 6. VISUALIZATION LOOP ---
fig, axes = plt.subplots(N_SAMPLES_TO_VISUALIZE, 3, figsize=(12, 4 * N_SAMPLES_TO_VISUALIZE))
test_iterator = iter(val_loader_extra_class)
for i in tqdm(range(len(val_loader_extra_class))):
  
    # try:
    #     # Get the next sample (masks is now GT Instance Mask)
    #     # gt_instance_mask_t is the R set (instance mask)
    #     inputs, gt_instance_mask_t = next(test_iterator)
    # except StopIteration:
    #     print(f"Only processed {i} samples. End of dataset reached.")
    #     # Adjust figure size if less than N_SAMPLES_TO_VISUALIZE samples were processed
    #     if i > 0:
    #         fig.set_size_inches(12, 4 * i)
    #     break
    # #print(np.unique(gt_instance_mask_t))
    inputs = inputs.to(DEVICE)
    gt_instance_mask_np = gt_instance_mask_t.squeeze(0).numpy() # R set (instance mask)
    if len(np.unique(gt_instance_mask_np)) != 2:
        print("Non binary!")
    # Derived Binary Mask for Dice
    #gt_binary_mask_t = (gt_instance_mask_t > 0).float()
    
    with torch.no_grad():
        outputs = model_4c(inputs)
    #print(outputs.shape)
    # Prediction: outputs is [1, 2, H, W]. argmax over channel dim (1)
    preds_binary_t = torch.argmax(outputs, dim=1) # Binary prediction tensor
    preds_binary_np = preds_binary_t.squeeze(0).cpu().numpy()
    #print(np.unique(preds_binary_np,return_counts=True)[1])
    # --- 7. METRIC CALCULATION ---
    #print(np.unique(preds_binary_np))
    # a) Dice Score (uses binary masks)
    # current_dice = dice_coefficient(
    #     preds_binary_t.float(), 
    #     gt_binary_mask_t.to(DEVICE).float()
    # )
    # all_dice_scores.append(current_dice)
    
    # b) SEG Score (uses instance masks)
    # Generate Predicted Instances (S) from the U-Net's binary prediction using CCA

    
    preds_instance_np, _  = label(preds_binary_np, structure=None)
    # print(len(np.unique(preds_instance_np)))
    # print(len(np.unique(gt_binary_mask_t)))
    # print("="*100)
    current_seg_score = segmentation_accuracy_seg_measure(preds_instance_np, gt_instance_mask_np)
    all_seg_scores.append(current_seg_score)
    # #print(current_seg_score)
    # # Original Image (Input)
    # input_image_np = inputs.squeeze().cpu().numpy()


    # --- 8. PLOTTING ---
    # if current_seg_score < 0.25:
    #     print(np.unique(gt_instance_mask_np))
    #     # Col 1: Original Image
    #     ax1 = axes[cnt, 0] if N_SAMPLES_TO_VISUALIZE > 1 else axes[0]
    #     ax1.imshow(input_image_np, cmap='gray')
    #     ax1.set_title(f"Image (Index {i})")
    #     ax1.axis('off')
        
    #     # Col 2: Ground Truth Mask (Instance IDs)
    #     ax2 = axes[cnt, 1] if N_SAMPLES_TO_VISUALIZE > 1 else axes[1]
    #     # Use 'gist_ncar' colormap for instance visualization
    #     ax2.imshow(gt_instance_mask_np, cmap='gist_ncar') 
    #     ax2.set_title("Ground Truth Instances (R)")
    #     ax2.axis('off')

    #     # Col 3: Predicted Mask (SEG Score)
    #     ax3 = axes[cnt, 2] if N_SAMPLES_TO_VISUALIZE > 1 else axes[2]
    #     # Plot the predicted instances S
    #     ax3.imshow(preds_instance_np, cmap='gist_ncar') 
    #     ax3.set_title(f"Predicted Instances (S)\nDice: {current_dice:.4f} | SEG: {current_seg_score:.4f}")
    #     ax3.axis('off')

    #     cnt += 1

# Adjust layout and show plot
plt.tight_layout()
plt.suptitle(f"U-Net Segmentation Results on Test Data (N={len(all_dice_scores)})", y=1.02, fontsize=16)
plt.show()

# Print overall average scores for the visualized batch
avg_seg = np.mean(all_seg_scores)
print(f"\n--- Evaluation Summary for Visualized Samples ---")
print(f"Average Dice Score: {avg_dice:.4f}")
print(f"Average SEG Score (Instance Accuracy): {avg_seg:.4f}")
# Out:
# 100%|██████████| 88/88 [00:10<00:00,  8.42it/s]
# --- Evaluation Summary for Visualized Samples ---
# Average Dice Score: 0.9821
# Average SEG Score (Instance Accuracy): 0.7097

# %%
# Boundary-aware model evaluation
model = smp.Unet(
    encoder_name="resnet34",       
    encoder_weights=None,          
    in_channels=1,                 
    classes=2,                    
).to(DEVICE)
cnt = 0
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval() # Set model to evaluation mode

# --- 5. DATA LOADING AND INFERENCE ---
# test_dataset = CellSegmentationDataset(BASE_PATH, val_indices)
# test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
# print("\nStarting inference on test samples...")
all_dice_scores = []
all_seg_scores = [] # New list for SEG scores

# test_iterator = iter(test_loader)

# # --- 6. VISUALIZATION LOOP ---
fig, axes = plt.subplots(N_SAMPLES_TO_VISUALIZE, 3, figsize=(12, 4 * N_SAMPLES_TO_VISUALIZE))
test_iterator = iter(val_loader_extra_class)
for i in tqdm(range(len(val_loader_extra_class))):
  
    # try:
    #     # Get the next sample (masks is now GT Instance Mask)
    #     # gt_instance_mask_t is the R set (instance mask)
    #     inputs, gt_instance_mask_t = next(test_iterator)
    # except StopIteration:
    #     print(f"Only processed {i} samples. End of dataset reached.")
    #     # Adjust figure size if less than N_SAMPLES_TO_VISUALIZE samples were processed
    #     if i > 0:
    #         fig.set_size_inches(12, 4 * i)
    #     break
    # #print(np.unique(gt_instance_mask_t))
    inputs = inputs.to(DEVICE)
    gt_instance_mask_np = gt_instance_mask_t.squeeze(0).numpy() # R set (instance mask)
    
    # Derived Binary Mask for Dice
    #gt_binary_mask_t = (gt_instance_mask_t > 0).float()
    
    with torch.no_grad():
        outputs = model(inputs)
    #print(outputs.shape)
    # Prediction: outputs is [1, 2, H, W]. argmax over channel dim (1)
    preds_binary_t = torch.argmax(outputs, dim=1) # Binary prediction tensor
    preds_binary_np = preds_binary_t.squeeze(0).cpu().numpy()
    #print(np.unique(preds_binary_np,return_counts=True)[1])
    # --- 7. METRIC CALCULATION ---
    #print(np.unique(preds_binary_np))
    # a) Dice Score (uses binary masks)
    # current_dice = dice_coefficient(
    #     preds_binary_t.float(), 
    #     gt_binary_mask_t.to(DEVICE).float()
    # )
    # all_dice_scores.append(current_dice)
    
    # b) SEG Score (uses instance masks)
    # Generate Predicted Instances (S) from the U-Net's binary prediction using CCA

    
    preds_instance_np, _  = label(preds_binary_np, structure=None)
    # print(len(np.unique(preds_instance_np)))
    # print(len(np.unique(gt_binary_mask_t)))
    # print("="*100)
    current_seg_score = segmentation_accuracy_seg_measure(preds_instance_np, gt_instance_mask_np)
    all_seg_scores.append(current_seg_score)
    # #print(current_seg_score)
    # # Original Image (Input)
    # input_image_np = inputs.squeeze().cpu().numpy()


    # --- 8. PLOTTING ---
    # if current_seg_score < 0.25:
    #     print(np.unique(gt_instance_mask_np))
    #     # Col 1: Original Image
    #     ax1 = axes[cnt, 0] if N_SAMPLES_TO_VISUALIZE > 1 else axes[0]
    #     ax1.imshow(input_image_np, cmap='gray')
    #     ax1.set_title(f"Image (Index {i})")
    #     ax1.axis('off')
        
    #     # Col 2: Ground Truth Mask (Instance IDs)
    #     ax2 = axes[cnt, 1] if N_SAMPLES_TO_VISUALIZE > 1 else axes[1]
    #     # Use 'gist_ncar' colormap for instance visualization
    #     ax2.imshow(gt_instance_mask_np, cmap='gist_ncar') 
    #     ax2.set_title("Ground Truth Instances (R)")
    #     ax2.axis('off')

    #     # Col 3: Predicted Mask (SEG Score)
    #     ax3 = axes[cnt, 2] if N_SAMPLES_TO_VISUALIZE > 1 else axes[2]
    #     # Plot the predicted instances S
    #     ax3.imshow(preds_instance_np, cmap='gist_ncar') 
    #     ax3.set_title(f"Predicted Instances (S)\nDice: {current_dice:.4f} | SEG: {current_seg_score:.4f}")
    #     ax3.axis('off')

    #     cnt += 1

# Adjust layout and show plot
plt.tight_layout()
plt.suptitle(f"U-Net Segmentation Results on Test Data (N={len(all_dice_scores)})", y=1.02, fontsize=16)
plt.show()

# Print overall average scores for the visualized batch
avg_seg = np.mean(all_seg_scores)
print(f"\n--- Evaluation Summary for Visualized Samples ---")
print(f"Average Dice Score: {avg_dice:.4f}")
print(f"Average SEG Score (Instance Accuracy): {avg_seg:.4f}")
